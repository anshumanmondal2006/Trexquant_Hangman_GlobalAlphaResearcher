# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode
# Out:
# /Users/amondal/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#these are the vowels in english dictionary
vowels = ['a', 'e', 'i', 'o', 'u']

# %%
# function to evaluate ratio of vowels to words
def vowel_count(clean_word):
    cnt = 0
    for i in clean_word:
        if i in vowels:
            cnt = cnt+1.0
    return cnt/len(clean_word)

# %%
#opens the given dictionary file (in txt format)
f = open("words_250000_train.txt", "r")
df = []
for x in f:
  df.append(x)

# %%
#replaces newline characters
for i in range(len(df)):
    df[i] =df[i].replace("\n", "")

# %%
letter=[]
for words in df:
    letter.append(vowel_count(words))
x = pd.Series(letter)
x.describe()
# Out:
# count    227300.000000
# mean          0.386889
# std           0.095527
# min           0.000000
# 25%           0.333333
# 50%           0.384615
# 75%           0.444444
# max           1.000000
# dtype: float64

# %%
#histogram to decide threshold for when to consider vowels
bins = np.arange(0.0, 1.0, 0.05)
plt.hist(x = letter, bins = bins)
# Out:
# (array([1.2490e+03, 2.0000e+00, 6.8100e+02, 1.7410e+03, 6.7780e+03,
#         3.2538e+04, 3.5853e+04, 3.6370e+04, 6.0189e+04, 1.2807e+04,
#         2.8992e+04, 7.8220e+03, 7.7600e+02, 1.1180e+03, 1.0800e+02,
#         1.8300e+02, 5.4000e+01, 1.0000e+00, 0.0000e+00]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95]),
#  <BarContainer object of 19 artists>)

# %%
#to check the longest word in the dictionary given 
max_l = 0
for words in df:
    if(len(words)>max_l):
        max_l = len(words)
print(max_l)
# Out:
# 29

# %%
n_word_dictionary = {i:[] for i in range(3, 30)}
count = 3
while count<=max_l:
    for words in df:
        if(len(words)>=count):
            for i in range(len(words)-count+1):
                #if words[i:i+count-1] not in n_word_dictionary[count]:
                n_word_dictionary[count].append(words[i:i+count]) 
    count = count+1

# %%
# function to find number of times a letter come in whole dictionary, keeping count of letter 1 if it comes in a word else 0
def func(new_dictionary):
    dictx = collections.Counter()
    for words in new_dictionary:
        temp = collections.Counter(words)
        for i in temp:
            temp[i] = 1
            dictx = dictx + temp
    return dictx

# %%
# function to generate a list of words which are substring in the original dictionary and of same length as clean word
def func2(n_word_dictionary, clean_word):
    new_dictionary = []
    l = len(clean_word)
    for dict_word in n_word_dictionary[l]:
        if re.match(clean_word,dict_word):
            new_dictionary.append(dict_word)
    return new_dictionary

# %%
HANGMAN_URL = "https://www.trexsim.com/trexsim/hangman"

class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.full_dictionary_common_letter_sorted = dict(collections.Counter("".join(self.full_dictionary)).most_common())

        max_length = 0
        for word in self.full_dictionary:
            if len(word) > max_length:
                max_length = len(word)

        self.positional_freq = {
            length: [collections.Counter() for _ in range(length)]
            for length in range(3, max_length + 1)
        }

        # This will store the frequency of letter pairs (bigrams)
        self.bigram_freq = collections.Counter()

        # Populate the models
        for word in self.full_dictionary:
            word_len = len(word)
            if word_len in self.positional_freq:
                for i, letter in enumerate(word):
                    self.positional_freq[word_len][i][letter] += 1
                    if i > 0:
                        self.bigram_freq[word[i-1:i+1]] += 1
    
        self.current_dictionary = []
        
    

    #the guess function-main part
        
    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_",".")
        
        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        '''
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        '''
        
        c = func(new_dictionary)
        
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # to get the most freq occuring unguessed letter so far
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                if letter in vowels and vowel_count(clean_word)>0.55:
                    self.guessed_letters.append(letter)
                    continue
                guess_letter = letter
                break
                
        if guess_letter == '!':
            new_dictionary = func2(n_word_dictionary, clean_word)
            c = func(new_dictionary)
            sorted_letter_count = c.most_common()
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    if letter in vowels and vowel_count(clean_word)>0.55:
                        self.guessed_letters.append(letter)
                        continue
                    guess_letter = letter
                    break
                    
    #a heuristic approach to look for substring patterns
        if guess_letter == '!':
            for frac in [0.75, 0.5, 0.33]:
                x = int(len(clean_word) * frac)
                if x < 3: 
                    break  
                c = collections.Counter()
                for i in range(len(clean_word) - x + 1):
                    s = clean_word[i:i+x]
                    new_dictionary = func2(n_word_dictionary, s)
                    temp = func(new_dictionary)
                    c += temp
                sorted_letter_count = c.most_common()
                for letter, instance_count in sorted_letter_count:
                    if letter not in self.guessed_letters:
                        guess_letter = letter
                        break
                if guess_letter != '!':
                    break
       
            
        # if no word matches get back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted.items()
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    if letter in vowels and vowel_count(clean_word)>0.55:
                        self.guessed_letters.append(letter)
                        continue
                    guess_letter = letter
                    break            
        
        return guess_letter
    


    

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        try:
            # response = self.session.request(
            response = requests.request(
                method or "GET",
                HANGMAN_URL + path,
                timeout=self.timeout,
                params=args,
                data=post_args)
        except requests.HTTPError as e:
            response = json.loads(e.read())
            raise HangmanAPIError(response)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="281fcd44448e92bbfd17461c3730f1", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
n = 50
start = 0
end = 0

for _ in range(n):
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() 
    if (_ == 0):
        start = total_practice_successes
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs

    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
    
    end = total_practice_successes
    print(f'Accuracy obtained in the run so far is {(end - start) /(_+1)}')
# Out:
# Successfully start a new game! Game ID: 92359f16e83b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ r e '}
# Guessing letter: o
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ r e '}
# Guessing letter: t
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ t _ r e '}
# Guessing letter: u
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ t _ r e '}
# Guessing letter: a
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ t a r e '}
# Guessing letter: h
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ t a r e '}
# Guessing letter: c
# Sever response: {'game_id': '92359f16e83b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e _ t a r e '}
# Guessing letter: n
# Sever response: {'game_id': '92359f16e83b', 'status': 'success', 'tries_remains': 3, 'word': 'c e n t a r e '}
# Successfully finished game: 92359f16e83b
# run 438 practice games out of an allotted 100,000. practice success rate so far = 0.454
# Accuracy obtained in the run so far is 1.0
# Successfully start a new game! Game ID: a5cd30086a3e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ a _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ a n '}
# Guessing letter: i
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ a n '}
# Guessing letter: m
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ m a n '}
# Guessing letter: r
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ r m a n '}
# Guessing letter: o
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ o o r m a n '}
# Guessing letter: d
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ o o r m a n '}
# Guessing letter: f
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'f _ o o r m a n '}
# Guessing letter: l
# Sever response: {'game_id': 'a5cd30086a3e', 'status': 'success', 'tries_remains': 3, 'word': 'f l o o r m a n '}
# Successfully finished game: a5cd30086a3e
# run 439 practice games out of an allotted 100,000. practice success rate so far = 0.456
# Accuracy obtained in the run so far is 1.0
# Successfully start a new game! Game ID: 0dc59508f7d3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ i _ i _ _ _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ i _ i _ _ t i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i n i _ i _ _ t i _ n '}
# Guessing letter: s
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's i n i _ i _ _ t i _ n '}
# Guessing letter: c
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's i n i _ i c _ t i _ n '}
# Guessing letter: a
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's i n i _ i c a t i _ n '}
# Guessing letter: f
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's i n i f i c a t i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '0dc59508f7d3', 'status': 'success', 'tries_remains': 5, 'word': 's i n i f i c a t i o n '}
# Successfully finished game: 0dc59508f7d3
# run 440 practice games out of an allotted 100,000. practice success rate so far = 0.457
# Accuracy obtained in the run so far is 1.0
# Successfully start a new game! Game ID: e4b2bc4e9a07. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e n _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e n _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ _ _ _ _ s '}
# Guessing letter: t
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ _ t _ _ s '}
# Guessing letter: m
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e n _ _ t _ _ s '}
# Guessing letter: l
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ _ t _ _ s '}
# Guessing letter: o
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ o t _ _ s '}
# Guessing letter: h
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ o t h _ s '}
# Guessing letter: d
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n d o t h _ s '}
# Guessing letter: u
# Sever response: {'game_id': 'e4b2bc4e9a07', 'status': 'failed', 'tries_remains': 0, 'word': 'e n d o t h _ s '}
# Failed game: e4b2bc4e9a07. Because of: # of tries exceeded!
# run 441 practice games out of an allotted 100,000. practice success rate so far = 0.456
# Accuracy obtained in the run so far is 0.75
# Successfully start a new game! Game ID: 937b3608b0b8. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ i _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ _ _ _ _ i _ i t _ '}
# Guessing letter: l
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ _ _ _ _ i l i t _ '}
# Guessing letter: b
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ _ _ _ b i l i t _ '}
# Guessing letter: y
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ _ _ _ b i l i t y '}
# Guessing letter: a
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ a _ _ a b i l i t y '}
# Guessing letter: n
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n _ n t _ a _ _ a b i l i t y '}
# Guessing letter: r
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n _ n t _ a _ _ a b i l i t y '}
# Guessing letter: c
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n _ n t _ a c _ a b i l i t y '}
# Guessing letter: e
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n _ n t e a c _ a b i l i t y '}
# Guessing letter: h
# Sever response: {'game_id': '937b3608b0b8', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n _ n t e a c h a b i l i t y '}
# Guessing letter: o
# Sever response: {'game_id': '937b3608b0b8', 'status': 'success', 'tries_remains': 5, 'word': 'n o n t e a c h a b i l i t y '}
# Successfully finished game: 937b3608b0b8
# run 442 practice games out of an allotted 100,000. practice success rate so far = 0.457
# Accuracy obtained in the run so far is 0.8
# Successfully start a new game! Game ID: 5c8f430b726c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ i _ _ i _ '}
# Guessing letter: s
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ i s _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ i s _ i c '}
# Guessing letter: t
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ i s t i c '}
# Guessing letter: n
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ _ _ i _ i s t i c '}
# Guessing letter: m
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n _ _ _ i _ i s t i c '}
# Guessing letter: u
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n _ u _ i _ i s t i c '}
# Guessing letter: l
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n _ u _ i l i s t i c '}
# Guessing letter: g
# Sever response: {'game_id': '5c8f430b726c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n _ u g i l i s t i c '}
# Guessing letter: p
# Sever response: {'game_id': '5c8f430b726c', 'status': 'success', 'tries_remains': 4, 'word': 'u n p u g i l i s t i c '}
# Successfully finished game: 5c8f430b726c
# run 443 practice games out of an allotted 100,000. practice success rate so far = 0.458
# Accuracy obtained in the run so far is 0.8333333333333334
# Successfully start a new game! Game ID: b2cfea95653f. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a '}
# Guessing letter: e
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ a '}
# Guessing letter: r
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ a '}
# Guessing letter: l
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ a '}
# Guessing letter: t
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ a '}
# Guessing letter: n
# Sever response: {'game_id': 'b2cfea95653f', 'status': 'success', 'tries_remains': 2, 'word': 'n i n a '}
# Successfully finished game: b2cfea95653f
# run 444 practice games out of an allotted 100,000. practice success rate so far = 0.459
# Accuracy obtained in the run so far is 0.8571428571428571
# Successfully start a new game! Game ID: 9e74fd40fbd4. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ e _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ e _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ e s _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ e s c _ '}
# Guessing letter: n
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e n e s c _ '}
# Guessing letter: o
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n e s c _ '}
# Guessing letter: h
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e n e s c _ '}
# Guessing letter: i
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n e s c _ '}
# Guessing letter: a
# Sever response: {'game_id': '9e74fd40fbd4', 'status': 'failed', 'tries_remains': 0, 'word': 'e n e s c _ '}
# Failed game: 9e74fd40fbd4. Because of: # of tries exceeded!
# run 445 practice games out of an allotted 100,000. practice success rate so far = 0.458
# Accuracy obtained in the run so far is 0.75
# Successfully start a new game! Game ID: ed7565ec21f1. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a r _ '}
# Guessing letter: d
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'd _ _ a r _ '}
# Guessing letter: s
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'd s _ a r _ '}
# Guessing letter: h
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'd s h a r _ '}
# Guessing letter: k
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd s h a r _ '}
# Guessing letter: p
# Sever response: {'game_id': 'ed7565ec21f1', 'status': 'success', 'tries_remains': 4, 'word': 'd s h a r p '}
# Successfully finished game: ed7565ec21f1
# run 446 practice games out of an allotted 100,000. practice success rate so far = 0.460
# Accuracy obtained in the run so far is 0.7777777777777778
# Successfully start a new game! Game ID: 547c556ab61a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ e s s _ e s s '}
# Guessing letter: n
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ e s s n e s s '}
# Guessing letter: l
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ l e s s n e s s '}
# Guessing letter: a
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ l e s s n e s s '}
# Guessing letter: p
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ l e s s n e s s '}
# Guessing letter: i
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ l e s s n e s s '}
# Guessing letter: u
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 3, 'word': 's u _ l e s s n e s s '}
# Guessing letter: t
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 2, 'word': 's u _ l e s s n e s s '}
# Guessing letter: d
# Sever response: {'game_id': '547c556ab61a', 'status': 'ongoing', 'tries_remains': 1, 'word': 's u _ l e s s n e s s '}
# Guessing letter: r
# Sever response: {'game_id': '547c556ab61a', 'status': 'failed', 'tries_remains': 0, 'word': 's u _ l e s s n e s s '}
# Failed game: 547c556ab61a. Because of: # of tries exceeded!
# run 447 practice games out of an allotted 100,000. practice success rate so far = 0.459
# Accuracy obtained in the run so far is 0.7
# Successfully start a new game! Game ID: c10f0769c308. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ i _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ t i _ _ _ t '}
# Guessing letter: s
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s t i _ _ _ t '}
# Guessing letter: p
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p e s t i _ _ _ t '}
# Guessing letter: l
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p e s t i _ _ _ t '}
# Guessing letter: a
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p e s t i _ _ _ t '}
# Guessing letter: c
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p e s t i _ _ c t '}
# Guessing letter: g
# Sever response: {'game_id': 'c10f0769c308', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p e s t i _ _ c t '}
# Guessing letter: o
# Sever response: {'game_id': 'c10f0769c308', 'status': 'failed', 'tries_remains': 0, 'word': 'p e s t i _ _ c t '}
# Failed game: c10f0769c308. Because of: # of tries exceeded!
# run 448 practice games out of an allotted 100,000. practice success rate so far = 0.458
# Accuracy obtained in the run so far is 0.6363636363636364
# Successfully start a new game! Game ID: 5d4cd0747088. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r '}
# Guessing letter: i
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i e r '}
# Guessing letter: a
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ i e r '}
# Guessing letter: l
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ i e r '}
# Guessing letter: m
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ i e r '}
# Guessing letter: s
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ i e r '}
# Guessing letter: n
# Sever response: {'game_id': '5d4cd0747088', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ i e r '}
# Guessing letter: t
# Sever response: {'game_id': '5d4cd0747088', 'status': 'success', 'tries_remains': 2, 'word': 't a t t i e r '}
# Successfully finished game: 5d4cd0747088
# run 449 practice games out of an allotted 100,000. practice success rate so far = 0.459
# Accuracy obtained in the run so far is 0.6666666666666666
# Successfully start a new game! Game ID: 7be30d3ce882. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ n _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ n _ _ i o n '}
# Guessing letter: t
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ n _ t i o n '}
# Guessing letter: a
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ n _ t i o n '}
# Guessing letter: s
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ n _ t i o n '}
# Guessing letter: r
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ n _ t i o n '}
# Guessing letter: c
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ n c t i o n '}
# Guessing letter: j
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ n c t i o n '}
# Guessing letter: u
# Sever response: {'game_id': '7be30d3ce882', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ u n c t i o n '}
# Guessing letter: f
# Sever response: {'game_id': '7be30d3ce882', 'status': 'success', 'tries_remains': 3, 'word': 'r e f u n c t i o n '}
# Successfully finished game: 7be30d3ce882
# run 450 practice games out of an allotted 100,000. practice success rate so far = 0.460
# Accuracy obtained in the run so far is 0.6923076923076923
# Successfully start a new game! Game ID: 5ccb41171f9f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ r _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o _ _ o r o _ _ '}
# Guessing letter: z
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'z o o _ _ o r o _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'z o o _ p o r o _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'z o o s p o r o _ s '}
# Guessing letter: u
# Sever response: {'game_id': '5ccb41171f9f', 'status': 'success', 'tries_remains': 3, 'word': 'z o o s p o r o u s '}
# Successfully finished game: 5ccb41171f9f
# run 451 practice games out of an allotted 100,000. practice success rate so far = 0.461
# Accuracy obtained in the run so far is 0.7142857142857143
# Successfully start a new game! Game ID: bdaa731ad199. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ i _ e _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ i _ e _ _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ i _ e _ _ _ i n g '}
# Guessing letter: t
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ t i _ e t t _ i n g '}
# Guessing letter: l
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ t i l e t t _ i n g '}
# Guessing letter: s
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'ongoing', 'tries_remains': 5, 'word': 's t i l e t t _ i n g '}
# Guessing letter: o
# Sever response: {'game_id': 'bdaa731ad199', 'status': 'success', 'tries_remains': 5, 'word': 's t i l e t t o i n g '}
# Successfully finished game: bdaa731ad199
# run 452 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Accuracy obtained in the run so far is 0.7333333333333333
# Successfully start a new game! Game ID: 1f70810821da. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ a _ e '}
# Guessing letter: t
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ _ _ _ a _ e '}
# Guessing letter: r
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ r _ _ a _ e '}
# Guessing letter: u
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ r _ _ a _ e '}
# Guessing letter: o
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ r _ _ a _ e '}
# Guessing letter: q
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 3, 'word': 't _ r _ _ a _ e '}
# Guessing letter: n
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ r _ _ a _ e '}
# Guessing letter: g
# Sever response: {'game_id': '1f70810821da', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ r _ _ a _ e '}
# Guessing letter: b
# Sever response: {'game_id': '1f70810821da', 'status': 'failed', 'tries_remains': 0, 'word': 't _ r _ _ a _ e '}
# Failed game: 1f70810821da. Because of: # of tries exceeded!
# run 453 practice games out of an allotted 100,000. practice success rate so far = 0.461
# Accuracy obtained in the run so far is 0.6875
# Successfully start a new game! Game ID: f47ef11039a3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ r _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ r _ _ e s '}
# Guessing letter: a
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a r a _ e s '}
# Guessing letter: c
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c _ a r a _ e s '}
# Guessing letter: h
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c h a r a _ e s '}
# Guessing letter: d
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'c h a r a _ e s '}
# Guessing letter: t
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c h a r a _ e s '}
# Guessing letter: b
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c h a r a _ e s '}
# Guessing letter: n
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c h a r a _ e s '}
# Guessing letter: m
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c h a r a _ e s '}
# Guessing letter: p
# Sever response: {'game_id': 'f47ef11039a3', 'status': 'failed', 'tries_remains': 0, 'word': 'c h a r a _ e s '}
# Failed game: f47ef11039a3. Because of: # of tries exceeded!
# run 454 practice games out of an allotted 100,000. practice success rate so far = 0.460
# Accuracy obtained in the run so far is 0.6470588235294118
# Successfully start a new game! Game ID: 0d33f0ad0627. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ l l _ '}
# Guessing letter: b
# Sever response: {'game_id': '0d33f0ad0627', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ _ l l _ '}
# Failed game: 0d33f0ad0627. Because of: # of tries exceeded!
# run 455 practice games out of an allotted 100,000. practice success rate so far = 0.459
# Accuracy obtained in the run so far is 0.6111111111111112
# Successfully start a new game! Game ID: b7104eb51a5a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ n _ _ _ _ _ _ e _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n i n _ _ i _ _ _ e _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n i n t _ i _ _ t e _ _ '}
# Guessing letter: u
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'u n i n t _ i _ _ t e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'u n i n t r i _ _ t e _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'u n i n t r i c _ t e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'u n i n t r i c a t e _ _ '}
# Guessing letter: d
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n i n t r i c a t e _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n i n t r i c a t e l _ '}
# Guessing letter: y
# Sever response: {'game_id': 'b7104eb51a5a', 'status': 'success', 'tries_remains': 4, 'word': 'u n i n t r i c a t e l y '}
# Successfully finished game: b7104eb51a5a
# run 456 practice games out of an allotted 100,000. practice success rate so far = 0.461
# Accuracy obtained in the run so far is 0.631578947368421
# Successfully start a new game! Game ID: 613cafbabc57. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ r e _ _ _ _ e _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n _ n r e _ _ _ _ e n _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n _ n r e c _ _ _ e n c _ '}
# Guessing letter: i
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n _ n r e c i _ i e n c _ '}
# Guessing letter: o
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n o n r e c i _ i e n c _ '}
# Guessing letter: p
# Sever response: {'game_id': '613cafbabc57', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n o n r e c i p i e n c _ '}
# Guessing letter: y
# Sever response: {'game_id': '613cafbabc57', 'status': 'success', 'tries_remains': 6, 'word': 'n o n r e c i p i e n c y '}
# Successfully finished game: 613cafbabc57
# run 457 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Accuracy obtained in the run so far is 0.65
# Successfully start a new game! Game ID: 7ede8daafc34. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ a _ _ a '}
# Guessing letter: l
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ a _ _ a '}
# Guessing letter: r
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ a r _ a '}
# Guessing letter: m
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ a r _ a '}
# Guessing letter: d
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i d a r _ a '}
# Guessing letter: k
# Sever response: {'game_id': '7ede8daafc34', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i d a r k a '}
# Guessing letter: b
# Sever response: {'game_id': '7ede8daafc34', 'status': 'success', 'tries_remains': 3, 'word': 'b i d a r k a '}
# Successfully finished game: 7ede8daafc34
# run 458 practice games out of an allotted 100,000. practice success rate so far = 0.463
# Accuracy obtained in the run so far is 0.6666666666666666
# Successfully start a new game! Game ID: 410551c7ac65. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ e _ _ _ r _ '}
# Guessing letter: o
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ e _ _ o r _ '}
# Guessing letter: s
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ e _ _ o r _ '}
# Guessing letter: t
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r _ _ e _ _ o r _ '}
# Guessing letter: y
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 4, 'word': 't r _ _ e _ _ o r _ '}
# Guessing letter: a
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 4, 'word': 't r a _ e _ _ o r _ '}
# Guessing letter: j
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r a _ e _ _ o r _ '}
# Guessing letter: c
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r a _ e _ _ o r _ '}
# Guessing letter: n
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r a _ e _ _ o r n '}
# Guessing letter: l
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r a _ e l _ o r n '}
# Guessing letter: v
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r a v e l _ o r n '}
# Guessing letter: i
# Sever response: {'game_id': '410551c7ac65', 'status': 'ongoing', 'tries_remains': 1, 'word': 't r a v e l _ o r n '}
# Guessing letter: f
# Sever response: {'game_id': '410551c7ac65', 'status': 'failed', 'tries_remains': 0, 'word': 't r a v e l _ o r n '}
# Failed game: 410551c7ac65. Because of: # of tries exceeded!
# run 459 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Accuracy obtained in the run so far is 0.6363636363636364
# Successfully start a new game! Game ID: 1ef379b7aaf5. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ i _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ i _ _ _ _ n _ '}
# Guessing letter: t
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ i _ _ _ _ n t '}
# Guessing letter: m
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ i _ _ _ _ n t '}
# Guessing letter: d
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n _ i _ _ _ _ n t '}
# Guessing letter: c
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ i _ _ _ _ n t '}
# Guessing letter: s
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ i _ _ _ _ n t '}
# Guessing letter: g
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ i g _ _ _ n t '}
# Guessing letter: h
# Sever response: {'game_id': '1ef379b7aaf5', 'status': 'failed', 'tries_remains': 0, 'word': 'i n _ i g _ _ _ n t '}
# Failed game: 1ef379b7aaf5. Because of: # of tries exceeded!
# run 460 practice games out of an allotted 100,000. practice success rate so far = 0.461
# Accuracy obtained in the run so far is 0.6086956521739131
# Successfully start a new game! Game ID: 8186fa51040f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e d '}
# Guessing letter: n
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ n _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ n _ _ e d '}
# Guessing letter: i
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ n i _ e d '}
# Guessing letter: o
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ n i _ e d '}
# Guessing letter: c
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c o _ n i _ e d '}
# Guessing letter: g
# Sever response: {'game_id': '8186fa51040f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c o g n i _ e d '}
# Guessing letter: z
# Sever response: {'game_id': '8186fa51040f', 'status': 'success', 'tries_remains': 3, 'word': 'c o g n i z e d '}
# Successfully finished game: 8186fa51040f
# run 461 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Accuracy obtained in the run so far is 0.625
# Successfully start a new game! Game ID: 54891e424810. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ s _ e _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t e _ s _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t e r s _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ t e r s _ e _ _ '}
# Guessing letter: f
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a f t e r s _ e _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a f t e r s _ e _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a f t e r s _ e _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a f t e r s _ e _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a f t e r s _ e l l '}
# Guessing letter: h
# Sever response: {'game_id': '54891e424810', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a f t e r s _ e l l '}
# Guessing letter: w
# Sever response: {'game_id': '54891e424810', 'status': 'success', 'tries_remains': 2, 'word': 'a f t e r s w e l l '}
# Successfully finished game: 54891e424810
# run 462 practice games out of an allotted 100,000. practice success rate so far = 0.463
# Accuracy obtained in the run so far is 0.64
# Successfully start a new game! Game ID: 4340a483be2e. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '4340a483be2e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ e '}
# Guessing letter: d
# Sever response: {'game_id': '4340a483be2e', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ e '}
# Failed game: 4340a483be2e. Because of: # of tries exceeded!
# run 463 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Accuracy obtained in the run so far is 0.6153846153846154
# Successfully start a new game! Game ID: 197fb713320d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ r _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ r _ _ _ e d '}
# Guessing letter: n
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ r _ _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ r _ _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t r _ _ _ e d '}
# Guessing letter: u
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ u t r _ _ u e d '}
# Guessing letter: o
# Sever response: {'game_id': '197fb713320d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'o u t r o _ u e d '}
# Guessing letter: g
# Sever response: {'game_id': '197fb713320d', 'status': 'success', 'tries_remains': 4, 'word': 'o u t r o g u e d '}
# Successfully finished game: 197fb713320d
# run 464 practice games out of an allotted 100,000. practice success rate so far = 0.463
# Accuracy obtained in the run so far is 0.6296296296296297
# Successfully start a new game! Game ID: a21384517464. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e r _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e r _ i _ '}
# Guessing letter: m
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ e r _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ e r _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e c _ _ _ e r _ i _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e c _ _ _ e r _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e c o _ _ e r o i _ '}
# Guessing letter: t
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e c o _ t e r o i _ '}
# Guessing letter: p
# Sever response: {'game_id': 'a21384517464', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p e c o p t e r o i _ '}
# Guessing letter: d
# Sever response: {'game_id': 'a21384517464', 'status': 'success', 'tries_remains': 3, 'word': 'p e c o p t e r o i d '}
# Successfully finished game: a21384517464
# run 465 practice games out of an allotted 100,000. practice success rate so far = 0.465
# Accuracy obtained in the run so far is 0.6428571428571429
# Successfully start a new game! Game ID: 2c55e03d5a0b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e n _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e n _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e n _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e n t _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ e n t _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l a _ e n t _ _ l '}
# Guessing letter: m
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l a m e n t _ _ l '}
# Guessing letter: b
# Sever response: {'game_id': '2c55e03d5a0b', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l a m e n t _ _ l '}
# ...
# Guessing letter: d
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ _ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ _ _ _ a _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r t _ _ _ t a t e _ '}
# Guessing letter: i
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r t _ _ _ t a t e _ '}
# Guessing letter: s
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r t _ _ s t a t e s '}
# Guessing letter: o
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'ongoing', 'tries_remains': 4, 'word': 'o r t _ o s t a t e s '}
# Guessing letter: h
# Sever response: {'game_id': '948f11d9a2d1', 'status': 'success', 'tries_remains': 4, 'word': 'o r t h o s t a t e s '}
# Successfully finished game: 948f11d9a2d1
# run 478 practice games out of an allotted 100,000. practice success rate so far = 0.475
# Accuracy obtained in the run so far is 0.7073170731707317
# Successfully start a new game! Game ID: 61ce5a3ae78b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ s _ e s s '}
# Guessing letter: n
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n _ n _ _ _ _ _ _ s n e s s '}
# Guessing letter: o
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ _ _ _ o _ s n e s s '}
# Guessing letter: u
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ _ _ u o u s n e s s '}
# Guessing letter: t
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n _ _ _ u o u s n e s s '}
# Guessing letter: c
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n _ _ c u o u s n e s s '}
# Guessing letter: p
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ _ c u o u s n e s s '}
# Guessing letter: a
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ a c u o u s n e s s '}
# Guessing letter: v
# Sever response: {'game_id': '61ce5a3ae78b', 'status': 'success', 'tries_remains': 3, 'word': 'n o n v a c u o u s n e s s '}
# Successfully finished game: 61ce5a3ae78b
# run 479 practice games out of an allotted 100,000. practice success rate so far = 0.476
# Accuracy obtained in the run so far is 0.7142857142857143
# Successfully start a new game! Game ID: 8858a711a307. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ a _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ a _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ _ a _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '8858a711a307', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ _ a _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '8858a711a307', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ _ _ a _ _ '}
# Failed game: 8858a711a307. Because of: # of tries exceeded!
# run 480 practice games out of an allotted 100,000. practice success rate so far = 0.475
# Accuracy obtained in the run so far is 0.6976744186046512
# Successfully start a new game! Game ID: bb0d55eebea0. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ a _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ a _ _ l e '}
# Guessing letter: r
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ a _ _ l e '}
# Guessing letter: p
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ a _ _ l e '}
# Guessing letter: m
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ m a _ _ l e '}
# Guessing letter: b
# Sever response: {'game_id': 'bb0d55eebea0', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ m a _ _ l e '}
# Failed game: bb0d55eebea0. Because of: # of tries exceeded!
# run 481 practice games out of an allotted 100,000. practice success rate so far = 0.474
# Accuracy obtained in the run so far is 0.6818181818181818
# Successfully start a new game! Game ID: c456120ba8ab. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ e d '}
# Guessing letter: l
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ l _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ l a _ e d '}
# Guessing letter: t
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ l a t e d '}
# Guessing letter: u
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ u l a t e d '}
# Guessing letter: r
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ _ _ u l a t e d '}
# Guessing letter: i
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e i _ _ u l a t e d '}
# Guessing letter: n
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e i n _ u l a t e d '}
# Guessing letter: s
# Sever response: {'game_id': 'c456120ba8ab', 'status': 'success', 'tries_remains': 6, 'word': 'r e i n s u l a t e d '}
# Successfully finished game: c456120ba8ab
# run 482 practice games out of an allotted 100,000. practice success rate so far = 0.475
# Accuracy obtained in the run so far is 0.6888888888888889
# Successfully start a new game! Game ID: 24a134723ba1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '24a134723ba1', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ _ e _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '24a134723ba1', 'status': 'failed', 'tries_remains': 0, 'word': 't _ _ e _ _ _ _ '}
# Failed game: 24a134723ba1. Because of: # of tries exceeded!
# run 483 practice games out of an allotted 100,000. practice success rate so far = 0.474
# Accuracy obtained in the run so far is 0.6739130434782609
# Successfully start a new game! Game ID: b323ee3296c6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ i _ _ _ _ i _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ i _ _ t _ i _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ i a _ t _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i _ _ i a n t _ i _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ i l l i a n t _ i _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r i l l i a n t _ i _ e '}
# Guessing letter: b
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': 'b r i l l i a n t _ i _ e '}
# Guessing letter: s
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 6, 'word': 'b r i l l i a n t _ i s e '}
# Guessing letter: h
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b r i l l i a n t _ i s e '}
# Guessing letter: w
# Sever response: {'game_id': 'b323ee3296c6', 'status': 'success', 'tries_remains': 5, 'word': 'b r i l l i a n t w i s e '}
# Successfully finished game: b323ee3296c6
# run 484 practice games out of an allotted 100,000. practice success rate so far = 0.475
# Accuracy obtained in the run so far is 0.6808510638297872
# Successfully start a new game! Game ID: f43978abd2ea. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ n _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a n _ _ i _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a n _ _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a n _ _ i _ t '}
# Guessing letter: r
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ a n _ _ i _ t '}
# Guessing letter: v
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ a n _ _ i _ t '}
# Guessing letter: c
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ a n _ _ i _ t '}
# Guessing letter: h
# Sever response: {'game_id': 'f43978abd2ea', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ a n _ _ i _ t '}
# Failed game: f43978abd2ea. Because of: # of tries exceeded!
# run 485 practice games out of an allotted 100,000. practice success rate so far = 0.474
# Accuracy obtained in the run so far is 0.6666666666666666
# Successfully start a new game! Game ID: 2c37ee1ea6da. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 4, 'word': 's a n _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 4, 'word': 's a n _ _ i '}
# Guessing letter: t
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 3, 'word': 's a n _ _ i '}
# Guessing letter: u
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 2, 'word': 's a n _ _ i '}
# Guessing letter: g
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'ongoing', 'tries_remains': 1, 'word': 's a n _ _ i '}
# Guessing letter: c
# Sever response: {'game_id': '2c37ee1ea6da', 'status': 'failed', 'tries_remains': 0, 'word': 's a n _ _ i '}
# Failed game: 2c37ee1ea6da. Because of: # of tries exceeded!
# run 486 practice games out of an allotted 100,000. practice success rate so far = 0.473
# Accuracy obtained in the run so far is 0.6530612244897959
# Successfully start a new game! Game ID: b5dc5fc1d6bd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r '}
# Guessing letter: i
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ i _ e r '}
# Guessing letter: a
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ e r '}
# Guessing letter: l
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ e r '}
# Guessing letter: d
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i _ e r '}
# Guessing letter: n
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ i _ e r '}
# Guessing letter: t
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ _ i _ e r '}
# Guessing letter: m
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ _ i _ e r '}
# Guessing letter: z
# Sever response: {'game_id': 'b5dc5fc1d6bd', 'status': 'failed', 'tries_remains': 0, 'word': 't _ _ i _ e r '}
# Failed game: b5dc5fc1d6bd. Because of: # of tries exceeded!
# run 487 practice games out of an allotted 100,000. practice success rate so far = 0.472
# Accuracy obtained in the run so far is 0.64

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    
    api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Playing  1  th game
# Playing  2  th game
# Playing  3  th game
# Playing  4  th game
# Playing  5  th game
# Playing  6  th game
# Playing  7  th game
# Playing  8  th game
# Playing  9  th game
# Playing  10  th game
# Playing  11  th game
# Playing  12  th game
# Playing  13  th game
# Playing  14  th game
# Playing  15  th game
# Playing  16  th game
# Playing  17  th game
# Playing  18  th game
# Playing  19  th game
# Playing  20  th game
# Playing  21  th game
# Playing  22  th game
# Playing  23  th game
# Playing  24  th game
# Playing  25  th game
# Playing  26  th game
# Playing  27  th game
# Playing  28  th game
# Playing  29  th game
# Playing  30  th game
# Playing  31  th game
# Playing  32  th game
# Playing  33  th game
# Playing  34  th game
# Playing  35  th game
# Playing  36  th game
# Playing  37  th game
# Playing  38  th game
# Playing  39  th game
# Playing  40  th game
# Playing  41  th game
# Playing  42  th game
# Playing  43  th game
# Playing  44  th game
# Playing  45  th game
# Playing  46  th game
# Playing  47  th game
# Playing  48  th game
# Playing  49  th game
# Playing  50  th game
# Playing  51  th game
# Playing  52  th game
# Playing  53  th game
# Playing  54  th game
# Playing  55  th game
# Playing  56  th game
# Playing  57  th game
# Playing  58  th game
# Playing  59  th game
# Playing  60  th game
# Playing  61  th game
# Playing  62  th game
# Playing  63  th game
# Playing  64  th game
# Playing  65  th game
# Playing  66  th game
# Playing  67  th game
# Playing  68  th game
# Playing  69  th game
# Playing  70  th game
# Playing  71  th game
# Playing  72  th game
# Playing  73  th game
# Playing  74  th game
# Playing  75  th game
# Playing  76  th game
# Playing  77  th game
# Playing  78  th game
# Playing  79  th game
# Playing  80  th game
# Playing  81  th game
# Playing  82  th game
# Playing  83  th game
# Playing  84  th game
# Playing  85  th game
# Playing  86  th game
# Playing  87  th game
# Playing  88  th game
# Playing  89  th game
# Playing  90  th game
# Playing  91  th game
# Playing  92  th game
# Playing  93  th game
# Playing  94  th game
# Playing  95  th game
# Playing  96  th game
# Playing  97  th game
# Playing  98  th game
# Playing  99  th game
# Playing  100  th game
# Playing  101  th game
# Playing  102  th game
# Playing  103  th game
# Playing  104  th game
# Playing  105  th game
# Playing  106  th game
# Playing  107  th game
# Playing  108  th game
# Playing  109  th game
# Playing  110  th game
# Playing  111  th game
# Playing  112  th game
# Playing  113  th game
# Playing  114  th game
# Playing  115  th game
# Playing  116  th game
# Playing  117  th game
# Playing  118  th game
# Playing  119  th game
# Playing  120  th game
# Playing  121  th game
# Playing  122  th game
# Playing  123  th game
# Playing  124  th game
# Playing  125  th game
# Playing  126  th game
# Playing  127  th game
# Playing  128  th game
# Playing  129  th game
# Playing  130  th game
# Playing  131  th game
# Playing  132  th game
# Playing  133  th game
# Playing  134  th game
# Playing  135  th game
# Playing  136  th game
# Playing  137  th game
# Playing  138  th game
# Playing  139  th game
# Playing  140  th game
# Playing  141  th game
# Playing  142  th game
# Playing  143  th game
# Playing  144  th game
# Playing  145  th game
# Playing  146  th game
# Playing  147  th game
# Playing  148  th game
# Playing  149  th game
# Playing  150  th game
# Playing  151  th game
# Playing  152  th game
# Playing  153  th game
# Playing  154  th game
# Playing  155  th game
# Playing  156  th game
# Playing  157  th game
# Playing  158  th game
# Playing  159  th game
# Playing  160  th game
# Playing  161  th game
# Playing  162  th game
# Playing  163  th game
# Playing  164  th game
# Playing  165  th game
# Playing  166  th game
# Playing  167  th game
# Playing  168  th game
# Playing  169  th game
# Playing  170  th game
# Playing  171  th game
# Playing  172  th game
# Playing  173  th game
# Playing  174  th game
# Playing  175  th game
# Playing  176  th game
# Playing  177  th game
# Playing  178  th game
# Playing  179  th game
# Playing  180  th game
# Playing  181  th game
# Playing  182  th game
# Playing  183  th game
# Playing  184  th game
# Playing  185  th game
# Playing  186  th game
# Playing  187  th game
# Playing  188  th game
# Playing  189  th game
# Playing  190  th game
# Playing  191  th game
# Playing  192  th game
# Playing  193  th game
# Playing  194  th game
# Playing  195  th game
# Playing  196  th game
# Playing  197  th game
# Playing  198  th game
# Playing  199  th game
# Playing  200  th game
# Playing  201  th game
# Playing  202  th game
# Playing  203  th game
# Playing  204  th game
# Playing  205  th game
# Playing  206  th game
# Playing  207  th game
# Playing  208  th game
# Playing  209  th game
# Playing  210  th game
# Playing  211  th game
# Playing  212  th game
# Playing  213  th game
# Playing  214  th game
# Playing  215  th game
# Playing  216  th game
# Playing  217  th game
# Playing  218  th game
# Playing  219  th game
# Playing  220  th game
# Playing  221  th game
# Playing  222  th game
# Playing  223  th game
# Playing  224  th game
# Playing  225  th game
# Playing  226  th game
# Playing  227  th game
# Playing  228  th game
# Playing  229  th game
# Playing  230  th game
# Playing  231  th game
# Playing  232  th game
# Playing  233  th game
# Playing  234  th game
# Playing  235  th game
# Playing  236  th game
# Playing  237  th game
# Playing  238  th game
# Playing  239  th game
# Playing  240  th game
# Playing  241  th game
# Playing  242  th game
# Playing  243  th game
# Playing  244  th game
# Playing  245  th game
# Playing  246  th game
# Playing  247  th game
# Playing  248  th game
# Playing  249  th game
# Playing  250  th game
# Playing  251  th game
# Playing  252  th game
# Playing  253  th game
# Playing  254  th game
# Playing  255  th game
# Playing  256  th game
# Playing  257  th game
# Playing  258  th game
# Playing  259  th game
# Playing  260  th game
# Playing  261  th game
# Playing  262  th game
# Playing  263  th game
# Playing  264  th game
# Playing  265  th game
# Playing  266  th game
# Playing  267  th game
# Playing  268  th game
# Playing  269  th game
# Playing  270  th game
# Playing  271  th game
# Playing  272  th game
# Playing  273  th game
# Playing  274  th game
# Playing  275  th game
# Playing  276  th game
# Playing  277  th game
# Playing  278  th game
# Playing  279  th game
# Playing  280  th game
# Playing  281  th game
# Playing  282  th game
# Playing  283  th game
# Playing  284  th game
# Playing  285  th game
# Playing  286  th game
# Playing  287  th game
# Playing  288  th game
# Playing  289  th game
# Playing  290  th game
# Playing  291  th game
# Playing  292  th game
# Playing  293  th game
# Playing  294  th game
# Playing  295  th game
# Playing  296  th game
# Playing  297  th game
# Playing  298  th game
# Playing  299  th game
# Playing  300  th game
# Playing  301  th game
# Playing  302  th game
# Playing  303  th game
# Playing  304  th game
# Playing  305  th game
# Playing  306  th game
# Playing  307  th game
# Playing  308  th game
# Playing  309  th game
# Playing  310  th game
# Playing  311  th game
# Playing  312  th game
# Playing  313  th game
# Playing  314  th game
# Playing  315  th game
# Playing  316  th game
# Playing  317  th game
# Playing  318  th game
# Playing  319  th game
# Playing  320  th game
# Playing  321  th game
# Playing  322  th game
# Playing  323  th game
# Playing  324  th game
# Playing  325  th game
# Playing  326  th game
# Playing  327  th game
# Playing  328  th game
# Playing  329  th game
# Playing  330  th game
# Playing  331  th game
# Playing  332  th game
# Playing  333  th game
# Playing  334  th game
# Playing  335  th game
# Playing  336  th game
# Playing  337  th game
# Playing  338  th game
# Playing  339  th game
# Playing  340  th game
# Playing  341  th game
# Playing  342  th game
# Playing  343  th game
# Playing  344  th game
# Playing  345  th game
# Playing  346  th game
# Playing  347  th game
# Playing  348  th game
# Playing  349  th game
# Playing  350  th game
# Playing  351  th game
# Playing  352  th game
# Playing  353  th game
# Playing  354  th game
# Playing  355  th game
# Playing  356  th game
# Playing  357  th game
# Playing  358  th game
# Playing  359  th game
# Playing  360  th game
# Playing  361  th game
# Playing  362  th game
# Playing  363  th game
# Playing  364  th game
# Playing  365  th game
# Playing  366  th game
# Playing  367  th game
# Playing  368  th game
# Playing  369  th game
# Playing  370  th game
# Playing  371  th game
# Playing  372  th game
# Playing  373  th game
# Playing  374  th game
# Playing  375  th game
# Playing  376  th game
# Playing  377  th game
# Playing  378  th game
# Playing  379  th game
# Playing  380  th game
# Playing  381  th game
# Playing  382  th game
# Playing  383  th game
# Playing  384  th game
# Playing  385  th game
# Playing  386  th game
# Playing  387  th game
# Playing  388  th game
# Playing  389  th game
# Playing  390  th game
# Playing  391  th game
# Playing  392  th game
# Playing  393  th game
# Playing  394  th game
# Playing  395  th game
# Playing  396  th game
# Playing  397  th game
# Playing  398  th game
# Playing  399  th game
# Playing  400  th game
# Playing  401  th game
# Playing  402  th game
# Playing  403  th game
# Playing  404  th game
# Playing  405  th game
# Playing  406  th game
# Playing  407  th game
# Playing  408  th game
# Playing  409  th game
# Playing  410  th game
# Playing  411  th game
# Playing  412  th game
# Playing  413  th game
# Playing  414  th game
# Playing  415  th game
# Playing  416  th game
# Playing  417  th game
# Playing  418  th game
# Playing  419  th game
# Playing  420  th game
# Playing  421  th game
# Playing  422  th game
# Playing  423  th game
# Playing  424  th game
# Playing  425  th game
# Playing  426  th game
# Playing  427  th game
# Playing  428  th game
# Playing  429  th game
# Playing  430  th game
# Playing  431  th game
# Playing  432  th game
# Playing  433  th game
# Playing  434  th game
# Playing  435  th game
# Playing  436  th game
# Playing  437  th game
# Playing  438  th game
# Playing  439  th game
# Playing  440  th game
# Playing  441  th game
# Playing  442  th game
# Playing  443  th game
# Playing  444  th game
# Playing  445  th game
# Playing  446  th game
# Playing  447  th game
# Playing  448  th game
# Playing  449  th game
# Playing  450  th game
# Playing  451  th game
# Playing  452  th game
# Playing  453  th game
# Playing  454  th game
# Playing  455  th game
# Playing  456  th game
# Playing  457  th game
# Playing  458  th game
# Playing  459  th game
# Playing  460  th game
# Playing  461  th game
# Playing  462  th game
# Playing  463  th game
# Playing  464  th game
# Playing  465  th game
# Playing  466  th game
# Playing  467  th game
# Playing  468  th game
# Playing  469  th game
# Playing  470  th game
# Playing  471  th game
# Playing  472  th game
# Playing  473  th game
# Playing  474  th game
# Playing  475  th game
# Playing  476  th game
# Playing  477  th game
# Playing  478  th game
# Playing  479  th game
# Playing  480  th game
# Playing  481  th game
# Playing  482  th game
# Playing  483  th game
# Playing  484  th game
# Playing  485  th game
# Playing  486  th game
# Playing  487  th game
# Playing  488  th game
# Playing  489  th game
# Playing  490  th game
# Playing  491  th game
# Playing  492  th game
# Playing  493  th game
# Playing  494  th game
# Playing  495  th game
# Playing  496  th game
# Playing  497  th game
# Playing  498  th game
# Playing  499  th game
# Playing  500  th game
# Playing  501  th game
# Playing  502  th game
# Playing  503  th game
# Playing  504  th game
# Playing  505  th game
# Playing  506  th game
# Playing  507  th game
# Playing  508  th game
# Playing  509  th game
# Playing  510  th game
# Playing  511  th game
# Playing  512  th game
# Playing  513  th game
# Playing  514  th game
# Playing  515  th game
# Playing  516  th game
# Playing  517  th game
# Playing  518  th game
# Playing  519  th game
# Playing  520  th game
# Playing  521  th game
# Playing  522  th game
# Playing  523  th game
# Playing  524  th game
# Playing  525  th game
# Playing  526  th game
# Playing  527  th game
# Playing  528  th game
# Playing  529  th game
# Playing  530  th game
# Playing  531  th game
# Playing  532  th game
# Playing  533  th game
# Playing  534  th game
# Playing  535  th game
# Playing  536  th game
# Playing  537  th game
# Playing  538  th game
# Playing  539  th game
# Playing  540  th game
# Playing  541  th game
# Playing  542  th game
# Playing  543  th game
# Playing  544  th game
# Playing  545  th game
# Playing  546  th game
# Playing  547  th game
# Playing  548  th game
# Playing  549  th game
# Playing  550  th game
# Playing  551  th game
# Playing  552  th game
# Playing  553  th game
# Playing  554  th game
# Playing  555  th game
# Playing  556  th game
# Playing  557  th game
# Playing  558  th game
# Playing  559  th game
# Playing  560  th game
# Playing  561  th game
# Playing  562  th game
# Playing  563  th game
# Playing  564  th game
# Playing  565  th game
# Playing  566  th game
# Playing  567  th game
# Playing  568  th game
# Playing  569  th game
# Playing  570  th game
# Playing  571  th game
# Playing  572  th game
# Playing  573  th game
# Playing  574  th game
# Playing  575  th game
# Playing  576  th game
# Playing  577  th game
# Playing  578  th game
# Playing  579  th game
# Playing  580  th game
# Playing  581  th game
# Playing  582  th game
# Playing  583  th game
# Playing  584  th game
# Playing  585  th game
# Playing  586  th game
# Playing  587  th game
# Playing  588  th game
# Playing  589  th game
# Playing  590  th game
# Playing  591  th game
# Playing  592  th game
# Playing  593  th game
# Playing  594  th game
# Playing  595  th game
# Playing  596  th game
# Playing  597  th game
# Playing  598  th game
# Playing  599  th game
# Playing  600  th game
# Playing  601  th game
# Playing  602  th game
# Playing  603  th game
# Playing  604  th game
# Playing  605  th game
# Playing  606  th game
# Playing  607  th game
# Playing  608  th game
# Playing  609  th game
# Playing  610  th game
# Playing  611  th game
# Playing  612  th game
# Playing  613  th game
# Playing  614  th game
# Playing  615  th game
# Playing  616  th game
# Playing  617  th game
# Playing  618  th game
# Playing  619  th game
# Playing  620  th game
# Playing  621  th game
# Playing  622  th game
# Playing  623  th game
# Playing  624  th game
# Playing  625  th game
# Playing  626  th game
# Playing  627  th game
# Playing  628  th game
# Playing  629  th game
# Playing  630  th game
# Playing  631  th game
# Playing  632  th game
# Playing  633  th game
# Playing  634  th game
# Playing  635  th game
# Playing  636  th game
# Playing  637  th game
# Playing  638  th game
# Playing  639  th game
# Playing  640  th game
# Playing  641  th game
# Playing  642  th game
# Playing  643  th game
# Playing  644  th game
# Playing  645  th game
# Playing  646  th game
# Playing  647  th game
# Playing  648  th game
# Playing  649  th game
# Playing  650  th game
# Playing  651  th game
# Playing  652  th game
# Playing  653  th game
# Playing  654  th game
# Playing  655  th game
# Playing  656  th game
# Playing  657  th game
# Playing  658  th game
# Playing  659  th game
# Playing  660  th game
# Playing  661  th game
# Playing  662  th game
# Playing  663  th game
# Playing  664  th game
# Playing  665  th game
# Playing  666  th game
# Playing  667  th game
# Playing  668  th game
# Playing  669  th game
# Playing  670  th game
# Playing  671  th game
# Playing  672  th game
# Playing  673  th game
# Playing  674  th game
# Playing  675  th game
# Playing  676  th game
# Playing  677  th game
# Playing  678  th game
# Playing  679  th game
# Playing  680  th game
# Playing  681  th game
# Playing  682  th game
# Playing  683  th game
# Playing  684  th game
# Playing  685  th game
# Playing  686  th game
# Playing  687  th game
# Playing  688  th game
# Playing  689  th game
# Playing  690  th game
# Playing  691  th game
# Playing  692  th game
# Playing  693  th game
# Playing  694  th game
# Playing  695  th game
# Playing  696  th game
# Playing  697  th game
# Playing  698  th game
# Playing  699  th game
# Playing  700  th game
# Playing  701  th game
# Playing  702  th game
# Playing  703  th game
# Playing  704  th game
# Playing  705  th game
# Playing  706  th game
# Playing  707  th game
# Playing  708  th game
# Playing  709  th game
# Playing  710  th game
# Playing  711  th game
# Playing  712  th game
# Playing  713  th game
# Playing  714  th game
# Playing  715  th game
# Playing  716  th game
# Playing  717  th game
# Playing  718  th game
# Playing  719  th game
# Playing  720  th game
# Playing  721  th game
# Playing  722  th game
# Playing  723  th game
# Playing  724  th game
# Playing  725  th game
# Playing  726  th game
# Playing  727  th game
# Playing  728  th game
# Playing  729  th game
# Playing  730  th game
# Playing  731  th game
# Playing  732  th game
# Playing  733  th game
# Playing  734  th game
# Playing  735  th game
# Playing  736  th game
# Playing  737  th game
# Playing  738  th game
# Playing  739  th game
# Playing  740  th game
# Playing  741  th game
# Playing  742  th game
# Playing  743  th game
# Playing  744  th game
# Playing  745  th game
# Playing  746  th game
# Playing  747  th game
# Playing  748  th game
# Playing  749  th game
# Playing  750  th game
# Playing  751  th game
# Playing  752  th game
# Playing  753  th game
# Playing  754  th game
# Playing  755  th game
# Playing  756  th game
# Playing  757  th game
# Playing  758  th game
# Playing  759  th game
# Playing  760  th game
# Playing  761  th game
# Playing  762  th game
# Playing  763  th game
# Playing  764  th game
# Playing  765  th game
# Playing  766  th game
# Playing  767  th game
# Playing  768  th game
# Playing  769  th game
# Playing  770  th game
# Playing  771  th game
# Playing  772  th game
# Playing  773  th game
# Playing  774  th game
# Playing  775  th game
# Playing  776  th game
# Playing  777  th game
# Playing  778  th game
# Playing  779  th game
# Playing  780  th game
# Playing  781  th game
# Playing  782  th game
# Playing  783  th game
# Playing  784  th game
# Playing  785  th game
# Playing  786  th game
# Playing  787  th game
# Playing  788  th game
# Playing  789  th game
# Playing  790  th game
# Playing  791  th game
# Playing  792  th game
# Playing  793  th game
# Playing  794  th game
# Playing  795  th game
# Playing  796  th game
# Playing  797  th game
# Playing  798  th game
# Playing  799  th game
# Playing  800  th game
# Playing  801  th game
# Playing  802  th game
# Playing  803  th game
# Playing  804  th game
# Playing  805  th game
# Playing  806  th game
# Playing  807  th game
# Playing  808  th game
# Playing  809  th game
# Playing  810  th game
# Playing  811  th game
# Playing  812  th game
# Playing  813  th game
# Playing  814  th game
# Playing  815  th game
# Playing  816  th game
# Playing  817  th game
# Playing  818  th game
# Playing  819  th game
# Playing  820  th game
# Playing  821  th game
# Playing  822  th game
# Playing  823  th game
# Playing  824  th game
# Playing  825  th game
# Playing  826  th game
# Playing  827  th game
# Playing  828  th game
# Playing  829  th game
# Playing  830  th game
# Playing  831  th game
# Playing  832  th game
# Playing  833  th game
# Playing  834  th game
# Playing  835  th game
# Playing  836  th game
# Playing  837  th game
# Playing  838  th game
# Playing  839  th game
# Playing  840  th game
# Playing  841  th game
# Playing  842  th game
# Playing  843  th game
# Playing  844  th game
# Playing  845  th game
# Playing  846  th game
# Playing  847  th game
# Playing  848  th game
# Playing  849  th game
# Playing  850  th game
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# OSError: [Errno 51] Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x3036c7820>: Failed to establish a new connection: [Errno 51] Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.trexsim.com', port=443): Max retries exceeded with url: /trexsim/hangman/new_game?practice=0&access_token=281fcd44448e92bbfd17461c3730f1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x3036c7820>: Failed to establish a new connection: [Errno 51] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[14], line 5
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 5 api.start_game(practice=0,verbose=False)
#       7 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       8 time.sleep(0.5)
#
# Cell In[12], line 158, in HangmanAPI.start_game(self, practice, verbose)
#     155 self.guessed_letters = []
#     156 self.current_dictionary = self.full_dictionary
# --> 158 response = self.request("/new_game", {"practice":practice})
#     159 if response.get('status')=="approved":
#     160     game_id = response.get('game_id')
#
# Cell In[12], line 225, in HangmanAPI.request(self, path, args, post_args, method)
#     221         args["access_token"] = self.access_token
#     223 try:
#     224     # response = self.session.request(
# --> 225     response = requests.request(
#     226         method or "GET",
#     227         HANGMAN_URL + path,
#     228         timeout=self.timeout,
#     229         params=args,
#     230         data=post_args)
#     231 except requests.HTTPError as e:
#     232     response = json.loads(e.read())
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.trexsim.com', port=443): Max retries exceeded with url: /trexsim/hangman/new_game?practice=0&access_token=281fcd44448e92bbfd17461c3730f1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x3036c7820>: Failed to establish a new connection: [Errno 51] Network is unreachable'))

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    
    api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[22], line 5
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 5 api.start_game(practice=0,verbose=False)
#       7 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       8 time.sleep(0.5)
#
# Cell In[16], line 158, in HangmanAPI.start_game(self, practice, verbose)
#     155 self.guessed_letters = []
#     156 self.current_dictionary = self.full_dictionary
# --> 158 response = self.request("/new_game", {"practice":practice})
#     159 if response.get('status')=="approved":
#     160     game_id = response.get('game_id')
#
# Cell In[16], line 250, in HangmanAPI.request(self, path, args, post_args, method)
#     247     raise HangmanAPIError('Maintype was not text, or querystring')
#     249 if result and isinstance(result, dict) and result.get("error"):
# --> 250     raise HangmanAPIError(result)
#     251 return result
#
# HangmanAPIError: {'error': 'Your account has been deactivated!'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# overall success rate = 0.575
